# %% [markdown]
# # Assignment 1.2 R/Python Refresher

# %%
# First I will import some needed libraries
import pandas as pd
from importlib import reload
import sys
import numpy as np
from imp import reload
import nltk
import matplotlib.pyplot as plt 
import matplotlib.gridspec as gridspec 
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Step 1: Write a summary of your data and identify at least two questions to explore visually with your data.

# %% [markdown]
# The Data set I used for this assignment is a Netflix Fee Excel file that shows the different cost for each Netflix subscription option. While also showing the number of movies, shows, and the total library size for each Country that Netflix offers services. The variables of this data set are Country_code, Country, Total Library Size, No. of TV Shows, No. of Movies, Cost Per Month - Basic ($), Cost Per Month - Standard ($), Cost Per Month - Premium ($).
#
# Questions:
#
# What is the difference between the number of tv shows and movies and does Netflix supply more movies or TV shows?
#
# Which country has the highest cost for a Netflix subscription?

# %% [markdown]
# ## Step 2: Create a histogram or bar graph from your data.

# %%
# I will first use pandas to pull the data to create a data frame to work from
Netflix_Data = pd.read_csv('Netflix-fee.csv')
Netflix_Data
# Out:
#    Country_code         Country  Total Library Size  No. of TV Shows  \
# 0            ar       Argentina                4760             3154
# 1            au       Australia                6114             4050
# 2            at         Austria                5640             3779
# 3            be         Belgium                4990             3374
# 4            bo         Bolivia                4991             3155
# ..          ...             ...                 ...              ...
# 60           ua         Ukraine                5336             3261
# 61           gb  United Kingdom                6643             4551
# 62           us   United States                5818             3826
# 63           uy         Uruguay                4989             3154
# 64           ve       Venezuela                4797             3154
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# ...

# %%
# Next I will check and what variables have NA values and what percentage of the variable is NA
Netflix_Data.isnull().sum()/len(Netflix_Data)
# Out:
# Country_code                     0.0
# Country                          0.0
# Total Library Size               0.0
# No. of TV Shows                  0.0
# No. of Movies                    0.0
# Cost Per Month - Basic ($)       0.0
# Cost Per Month - Standard ($)    0.0
# Cost Per Month - Premium ($)     0.0
# dtype: float64

# %% [markdown]
# As seen above we do not have any variables with missing data so I will no move on and start to create some visualiztions.

# %%
# I will nw create a bar chart that show the Country and the Cost Per Month for Premium subscriptions 
plt.figure(figsize=(15,10))
ax = sns.barplot(x="Country", y="Cost Per Month - Premium ($)", data=Netflix_Data)
plt.xticks(rotation= 90);

# %%
# I will now check to see which country has the highest cost for
# a premium subscription. Which will show us the exact cost as seen in the graph above
Netflix_Data[Netflix_Data['Cost Per Month - Premium ($)'] == Netflix_Data['Cost Per Month - Premium ($)'].max()]
# Out:
#    Country_code        Country  Total Library Size  No. of TV Shows  \
# 33           li  Liechtenstein                3048             1712
# 56           ch    Switzerland                5506             3654
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 33           1336                       12.88                          20.46
# 56           1852                       12.88                          20.46
#
#     Cost Per Month - Premium ($)
# 33                         26.96
# 56                         26.96

# %% [markdown]
# As seen above we see that the highest Cost Per Month for Premium is 26.96 a month and is in Liechtenstein and Switzerland

# %% [markdown]
# ## Step 3: Create a boxplot from your data.

# %%
# I will now create a boxplot for the totl library size by the country code. With the use of Pandas
Netflix_Data.boxplot(by ='Country_code', column =['Total Library Size'], grid = False)
# Out:
# <AxesSubplot:title={'center':'Total Library Size'}, xlabel='Country_code'>

# %% [markdown]
# ## Step 4: Create a bivariate plot from your data.

# %%
# I will now use matplotlib to create a Bivariate line plot 
Netflix_Data.plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# When creating a line chart it is great to make it bivariate. As the line in this chart can use multiple variables as it allows us to use ultiple variables. As seen above we can see all our variables such as Total Library Size, No. of TV Shows, No. of Movies, Cost Per Month - Basic, Cost Per Month - Standard, Cost Per Month - Premium

# %% [markdown]
# ## Step 5: Create any additional visualizations that will help to answer the question(s) you want to answer.

# %%
# I will now create a heat map visualization to show the 
# differences and similarities between the different variables
plt.figure(figsize=(15,10))
sns.heatmap(Netflix_Data.corr(), annot=True);

# %%
# I will now create a bar chart for the top 10 cost for the 
# basic subscription with the use of matplotlib.pyplot.
plt.figure(figsize = (12,7))
top_10 = Netflix_Data['Country'][:10]
chart = Netflix_Data.groupby(top_10)['Cost Per Month - Basic ($)'].sum().sort_values(ascending = False).plot(kind = 'bar', 
                                                                                                  color = 'green')
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45)
plt.title('Top 10 of Country based on Total Basic Cost Per Month', fontsize = 15, pad = 12)
plt.xlabel('Country', fontsize = 12)
plt.ylabel('Cost Per Month - Basic ($)', fontsize = 12)
plt.show()

# %% [markdown]
# As seen above we see that the country with the highest cost per month for the basic subscription is belgium at a cost of about 10 dollars and the lowest cost of the top 10 is argentina which is right under 4 dollars a month.

# %% [markdown]
# ## Step 6: Summarize your results and make a conclusion. Explain how you arrived at this conclusion and how your visualizations support your conclusion.

# %% [markdown]
# As I worked through this data set, I created several visualizations for my Netflix fee data sets. Throughout this project I verified with a bivariate plot that Netflix has an all-around higher number of tv shows compared to the number of movies. While also learning that the country with the highest cost for the basic Netflix subscription is just over 10 dollars a month. While the cost drops to under 4 dollars for Argentina most other countries that did not make the top ten for cost. Which shows us that we have more options for TV shows instead of movies while the cost can vary depending on the country you are living in. Also these Visualizations support my conclusion as we see that Netflix invests more in TV shows and has for the most part has a low cost for a basic subscription for most countries under 4 dollars.
